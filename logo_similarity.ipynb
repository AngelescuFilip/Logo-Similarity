# %%
import pandas as pd

# Load parquet file
df = pd.read_parquet("logos.snappy.parquet")

domains = df['domain'].unique().tolist()

# %%
with open("domains.txt", "w") as f:
    for domain in domains:
        f.write(domain + "\n")

# %% [markdown]
# ## Scrape websites

# %%
import os

os.system('python scraper_crawl.py')

# %% [markdown]
# ## Extract logos from the html files

# %%
import os

# Set the path to your folder
folder_path = 'scraped_domains_html'

for filename in os.listdir(folder_path):
    if filename.startswith('www.'):
        new_name = filename.replace('www.', '', 1)
        old_path = os.path.join(folder_path, filename)
        new_path = os.path.join(folder_path, new_name)
        os.rename(old_path, new_path)
        print(f'Renamed: {filename} -> {new_name}')

# %%
from logo_extractor import extract_logo_url_from_html

folder_path = "scraped_domains_html"
logos = extract_logo_url_from_html(folder_path)

# %%
## Remove prefix
for entry in logos:
    if entry['logo_url'].startswith("https://"):
        entry['logo_url'] = entry['logo_url'].replace("https://", "", 1)

    if entry['logo_url'].startswith("http://"):
        entry['logo_url'] = entry['logo_url'].replace("http://", "", 1)

# %%
import json

## Prepare logos image paths for download by removing "NO_LOGO_FOUND" from the entries
filtered_logos = [entry for entry in logos if entry['logo_url'] != 'NO_LOGO_FOUND']
# Save list to JSON
with open("logos_image_paths.json", "w") as f:
    json.dump(filtered_logos, f)

# %%
## Download Logos
import os

os.system('python flaresolverr_logo_download.py')

# %%
## Get the failed domains
downloaded_domains = [os.path.splitext(f)[0] for f in os.listdir('logos') if os.path.isfile(os.path.join('logos', f))]

with open('domains.txt', 'r') as file:
    all_domains = [line.strip() for line in file]

failed_domains = [domain for domain in all_domains if domain not in downloaded_domains]

# %%
len(failed_domains)
# Out:
# 208

# %%
temp = [os.path.splitext(f)[0] for f in os.listdir('logos') if os.path.isfile(os.path.join('logos', f))]

# %%
len(temp)
# Out:
# 1474

# %% [markdown]
# ## Fill the missing logo urls

# %%
from dotenv import load_dotenv
import os
import requests
from io import BytesIO
from PIL import Image
import time

load_dotenv()
LOGODEV_API_KEY = os.getenv("LOGODEV_API_KEY")

# %%
def is_valid_image_url(url, content=None):
    try:
        if content is None:
            response = requests.get(url, timeout=5)
            if response.status_code != 200:
                return False
            content = response.content
        img = Image.open(BytesIO(content))
        return img.width > 1 and img.height > 1
    except Exception as e:
        print(f"⚠️ Image validation failed for {url}: {e}")
        return False

def get_logo_logodev(domain):
    url = f"https://img.logo.dev/{domain}?token={LOGODEV_API_KEY}&fallback=404"
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200 and response.headers["Content-Type"].startswith("image"):
            return url, 200
        elif response.status_code == 202:
            print(f"🕒 Logo.dev is processing {domain} (202)")
            return None, 202
        elif response.status_code == 404:
            print(f"🚫 Logo.dev: No logo for {domain} (404)")
            return None, 404
        else:
            print(f"🟥 Logo.dev failed for {domain} (status {response.status_code})")
            return None, response.status_code
    except Exception as e:
        print(f"⚠️ Logo.dev request error for {domain}: {e}")
        return None, None

def get_logo_clearbit(domain):
    url = f"https://logo.clearbit.com/{domain}"
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200 and response.headers["Content-Type"].startswith("image"):
            if is_valid_image_url(url, response.content):
                return url, 200
            else:
                print(f"🟥 Clearbit returned invalid image for {domain}")
                return None, 200
        else:
            print(f"🟥 Clearbit failed for {domain} (status {response.status_code})")
            return None, response.status_code
    except Exception as e:
        print(f"⚠️ Clearbit error for {domain}: {e}")
        return None, None

# %%
def fetch_logos_for_domains(domains, use_logodev=True, use_clearbit=True):
    results = []
    pending_logos = []

    # Initial lookup
    for domain in domains:
        print(f"🔍 Looking for logo for: {domain}")
        logo_url = None

        # Try Logo.dev
        if use_logodev:
            logo_url_dev, status = get_logo_logodev(domain)
            if logo_url_dev:
                logo_url = logo_url_dev
            elif status == 202:
                print(f"⏳ Logo.dev is processing {domain}")
                pending_logos.append(domain)

        # Try Clearbit if no logo yet
        if not logo_url and use_clearbit:
            logo_url_clearbit, status = get_logo_clearbit(domain)
            if logo_url_clearbit:
                logo_url = logo_url_clearbit

        results.append({
            "domain": domain,
            "logo_url": logo_url  # might still be None here
        })

    # Retry pending domains from Logo.dev
    if pending_logos:
        print(f"\n🔁 Waiting to recheck {len(pending_logos)} pending logos from Logo.dev...")
        time.sleep(240)  # wait 4 minutes
        for domain in pending_logos:
            logo_url, status = get_logo_logodev(domain)
            if logo_url:
                print(f"✅ Logo now available for {domain}")
                # Update the entry in results
                for entry in results:
                    if entry["domain"] == domain and not entry["logo_url"]:
                        entry["logo_url"] = logo_url

    # Final fallback: set "LOGO_NOT_FOUND" if nothing was found
    for entry in results:
        if not entry["logo_url"]:
            entry["logo_url"] = 'NO_LOGO_FOUND'

    return results

# %%
failed_domains = fetch_logos_for_domains(failed_domains)
# Out:
# 🔍 Looking for logo for: xella-colloquium.berlin
# 🔍 Looking for logo for: secureparkinghi.com
# 🔍 Looking for logo for: rheine.schule
# 🔍 Looking for logo for: ford.pl.ua
# 🔍 Looking for logo for: adecco.cl
# 🔍 Looking for logo for: pcllawyersfrankston.com.au
# 🔍 Looking for logo for: wurth.com.uy
# 🔍 Looking for logo for: renaultchiva.com
# 🔍 Looking for logo for: medef-artois.fr
# 🔍 Looking for logo for: medef-bearnetsoule.com
# 🔍 Looking for logo for: chicco.pl
# 🚫 Logo.dev: No logo for chicco.pl (404)
# 🟥 Clearbit failed for chicco.pl (status 404)
# 🔍 Looking for logo for: rotaryclubofessex.com
# 🔍 Looking for logo for: toofacedcosmetics.jp
# 🔍 Looking for logo for: rubiomonocoat.com.au
# 🔍 Looking for logo for: spitexaadorf.ch
# 🔍 Looking for logo for: metlife.co.kr
# 🔍 Looking for logo for: toyotafocsani.ro
# 🔍 Looking for logo for: secureparking.co.id
# 🔍 Looking for logo for: mazda-angola-autozuid.com
# 🔍 Looking for logo for: nikonschool.de
# 🔍 Looking for logo for: toyota-annecy.fr
# 🔍 Looking for logo for: toyota-rillieux.fr
# 🔍 Looking for logo for: chicco.ru
# 🚫 Logo.dev: No logo for chicco.ru (404)
# 🟥 Clearbit failed for chicco.ru (status 404)
# 🔍 Looking for logo for: subaru-bd.com
# 🔍 Looking for logo for: toyotaortakoy.com.tr
# 🔍 Looking for logo for: mazda-uae.com
# 🔍 Looking for logo for: propertyfinder.com
# 🔍 Looking for logo for: tapflo.se
# 🔍 Looking for logo for: toyota-lyonsud.fr
# 🔍 Looking for logo for: gs1my.org
# 🔍 Looking for logo for: wurth.sk
# 🔍 Looking for logo for: ampersand-world.com
# 🔍 Looking for logo for: portadoors.com
# 🔍 Looking for logo for: solatube.pt

# %%
failed_domains
# Out:
# [{'domain': 'xella-colloquium.berlin',
#   'logo_url': 'https://img.logo.dev/xella-colloquium.berlin?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'secureparkinghi.com',
#   'logo_url': 'https://img.logo.dev/secureparkinghi.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'rheine.schule',
#   'logo_url': 'https://img.logo.dev/rheine.schule?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'ford.pl.ua',
#   'logo_url': 'https://img.logo.dev/ford.pl.ua?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'adecco.cl',
#   'logo_url': 'https://img.logo.dev/adecco.cl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'pcllawyersfrankston.com.au',
#   'logo_url': 'https://img.logo.dev/pcllawyersfrankston.com.au?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.com.uy',
#   'logo_url': 'https://img.logo.dev/wurth.com.uy?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'renaultchiva.com',
#   'logo_url': 'https://img.logo.dev/renaultchiva.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef-artois.fr',
#   'logo_url': 'https://img.logo.dev/medef-artois.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef-bearnetsoule.com',
#   'logo_url': 'https://img.logo.dev/medef-bearnetsoule.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'chicco.pl', 'logo_url': 'LOGO_NOT_FOUND'},
#  {'domain': 'rotaryclubofessex.com',
#   'logo_url': 'https://img.logo.dev/rotaryclubofessex.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toofacedcosmetics.jp',
#   'logo_url': 'https://img.logo.dev/toofacedcosmetics.jp?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'rubiomonocoat.com.au',
#   'logo_url': 'https://img.logo.dev/rubiomonocoat.com.au?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'spitexaadorf.ch',
#   'logo_url': 'https://img.logo.dev/spitexaadorf.ch?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'metlife.co.kr',
#   'logo_url': 'https://img.logo.dev/metlife.co.kr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyotafocsani.ro',
#   'logo_url': 'https://img.logo.dev/toyotafocsani.ro?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'secureparking.co.id',
#   'logo_url': 'https://img.logo.dev/secureparking.co.id?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'mazda-angola-autozuid.com',
#   'logo_url': 'https://img.logo.dev/mazda-angola-autozuid.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'nikonschool.de',
#   'logo_url': 'https://img.logo.dev/nikonschool.de?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyota-annecy.fr',
#   'logo_url': 'https://img.logo.dev/toyota-annecy.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyota-rillieux.fr',
#   'logo_url': 'https://img.logo.dev/toyota-rillieux.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'chicco.ru', 'logo_url': 'LOGO_NOT_FOUND'},
#  {'domain': 'subaru-bd.com',
#   'logo_url': 'https://img.logo.dev/subaru-bd.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyotaortakoy.com.tr',
#   'logo_url': 'https://img.logo.dev/toyotaortakoy.com.tr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'mazda-uae.com',
#   'logo_url': 'https://img.logo.dev/mazda-uae.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'propertyfinder.com',
#   'logo_url': 'https://img.logo.dev/propertyfinder.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'pingusenglishbd.com', 'logo_url': 'LOGO_NOT_FOUND'},
#  {'domain': 'aamcovinelandnj.com',
#   'logo_url': 'https://img.logo.dev/aamcovinelandnj.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.lk',
#   'logo_url': 'https://img.logo.dev/wurth.lk?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'tgmresearch.vn',
#   'logo_url': 'https://img.logo.dev/tgmresearch.vn?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'intersport.si',
#   'logo_url': 'https://img.logo.dev/intersport.si?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'santander.pt',
#   'logo_url': 'https://img.logo.dev/santander.pt?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'suttontools.co.nz',
#   'logo_url': 'https://img.logo.dev/suttontools.co.nz?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'renault.pe',
#   'logo_url': 'https://img.logo.dev/renault.pe?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.com.vn',
#   'logo_url': 'https://img.logo.dev/wurth.com.vn?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'synlab.hr',
#   'logo_url': 'https://img.logo.dev/synlab.hr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyotaconstanta.ro',
#   'logo_url': 'https://img.logo.dev/toyotaconstanta.ro?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'pkffinconta.ro',
#   'logo_url': 'https://img.logo.dev/pkffinconta.ro?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'mcvitiesindia.com',
#   'logo_url': 'https://img.logo.dev/mcvitiesindia.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'pingusenglish.ac.th',
#   'logo_url': 'https://img.logo.dev/pingusenglish.ac.th?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef-essonne.org',
#   'logo_url': 'https://img.logo.dev/medef-essonne.org?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wordans.de',
#   'logo_url': 'https://img.logo.dev/wordans.de?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyotabucurestinord.ro',
#   'logo_url': 'https://img.logo.dev/toyotabucurestinord.ro?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.hu',
#   'logo_url': 'https://img.logo.dev/wurth.hu?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'adeccome.com',
#   'logo_url': 'https://img.logo.dev/adeccome.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'trisa.bg',
#   'logo_url': 'https://img.logo.dev/trisa.bg?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'nestle.ro',
#   'logo_url': 'https://img.logo.dev/nestle.ro?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'shahshalalfood.com',
#   'logo_url': 'https://img.logo.dev/shahshalalfood.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'invisalign.co.il',
#   'logo_url': 'https://img.logo.dev/invisalign.co.il?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'linexswfl.com',
#   'logo_url': 'https://img.logo.dev/linexswfl.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'honda.com.ng',
#   'logo_url': 'https://img.logo.dev/honda.com.ng?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'tapflo.co.za',
#   'logo_url': 'https://img.logo.dev/tapflo.co.za?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'whirlpool.com.hk',
#   'logo_url': 'https://img.logo.dev/whirlpool.com.hk?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'metlife.com.cy',
#   'logo_url': 'https://img.logo.dev/metlife.com.cy?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'carlsjr.com.my',
#   'logo_url': 'https://img.logo.dev/carlsjr.com.my?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef-beziers.fr',
#   'logo_url': 'https://img.logo.dev/medef-beziers.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'hondaheritagecenter.com',
#   'logo_url': 'https://img.logo.dev/hondaheritagecenter.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'mazdalanka.lk',
#   'logo_url': 'https://img.logo.dev/mazdalanka.lk?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'veka.com.sg',
#   'logo_url': 'https://img.logo.dev/veka.com.sg?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'captrain.pl',
#   'logo_url': 'https://img.logo.dev/captrain.pl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'nelsonlabsbozeman.com',
#   'logo_url': 'https://img.logo.dev/nelsonlabsbozeman.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'sitech-ohio.com',
#   'logo_url': 'https://img.logo.dev/sitech-ohio.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'sanlorenzo.com.pe',
#   'logo_url': 'https://img.logo.dev/sanlorenzo.com.pe?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'kiamotors.com.kh',
#   'logo_url': 'https://img.logo.dev/kiamotors.com.kh?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'mapfre.com.py',
#   'logo_url': 'https://img.logo.dev/mapfre.com.py?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef-aude.com',
#   'logo_url': 'https://img.logo.dev/medef-aude.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'duracell.in',
#   'logo_url': 'https://img.logo.dev/duracell.in?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'allianzportugal.pt', 'logo_url': 'LOGO_NOT_FOUND'},
#  {'domain': 'seqens.fi',
#   'logo_url': 'https://img.logo.dev/seqens.fi?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyotaploiesti.ro',
#   'logo_url': 'https://img.logo.dev/toyotaploiesti.ro?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'premiumproperties.com',
#   'logo_url': 'https://img.logo.dev/premiumproperties.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'yves-rocher.at',
#   'logo_url': 'https://img.logo.dev/yves-rocher.at?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'tapflo.kz',
#   'logo_url': 'https://img.logo.dev/tapflo.kz?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'duracell.com.tr',
#   'logo_url': 'https://img.logo.dev/duracell.com.tr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'yves-rocher.se',
#   'logo_url': 'https://img.logo.dev/yves-rocher.se?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'ikea.com.tw',
#   'logo_url': 'https://img.logo.dev/ikea.com.tw?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'oaklandwoodfloors.net', 'logo_url': 'LOGO_NOT_FOUND'},
#  {'domain': 'decathlon.com.br',
#   'logo_url': 'https://img.logo.dev/decathlon.com.br?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'davesmithfordonline.net',
#   'logo_url': 'https://img.logo.dev/davesmithfordonline.net?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'venturelightingme.com',
#   'logo_url': 'https://img.logo.dev/venturelightingme.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'tupperware.gr',
#   'logo_url': 'https://img.logo.dev/tupperware.gr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyota-corbeil.fr',
#   'logo_url': 'https://img.logo.dev/toyota-corbeil.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyota-montluel.fr',
#   'logo_url': 'https://img.logo.dev/toyota-montluel.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'mazda.com.kh',
#   'logo_url': 'https://img.logo.dev/mazda.com.kh?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyota-chartres.fr',
#   'logo_url': 'https://img.logo.dev/toyota-chartres.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wuerth.com.ph',
#   'logo_url': 'https://img.logo.dev/wuerth.com.ph?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'thebodyshop.com.br',
#   'logo_url': 'https://img.logo.dev/thebodyshop.com.br?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.co.ke',
#   'logo_url': 'https://img.logo.dev/wurth.co.ke?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'yvesrocher.com.tr',
#   'logo_url': 'https://img.logo.dev/yvesrocher.com.tr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef79.fr',
#   'logo_url': 'https://img.logo.dev/medef79.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'renaultpachuca.com.mx', 'logo_url': 'LOGO_NOT_FOUND'},
#  {'domain': 'invisalign.co.uk',
#   'logo_url': 'https://img.logo.dev/invisalign.co.uk?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'adecco.ie',
#   'logo_url': 'https://img.logo.dev/adecco.ie?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'overheaddoorcompanyjackson.com',
#   'logo_url': 'https://img.logo.dev/overheaddoorcompanyjackson.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'mapfre.com.uy',
#   'logo_url': 'https://img.logo.dev/mapfre.com.uy?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef-nouvelle-aquitaine.fr',
#   'logo_url': 'https://img.logo.dev/medef-nouvelle-aquitaine.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'subaru.mt',
#   'logo_url': 'https://img.logo.dev/subaru.mt?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef-anjou.fr',
#   'logo_url': 'https://img.logo.dev/medef-anjou.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'aamco-corpuschristi.com',
#   'logo_url': 'https://img.logo.dev/aamco-corpuschristi.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'path-solutions.com',
#   'logo_url': 'https://img.logo.dev/path-solutions.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'pixibeauty.co.uk',
#   'logo_url': 'https://img.logo.dev/pixibeauty.co.uk?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'invisalign.fr',
#   'logo_url': 'https://img.logo.dev/invisalign.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'takeda.nl',
#   'logo_url': 'https://img.logo.dev/takeda.nl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'pingusenglish.com',
#   'logo_url': 'https://img.logo.dev/pingusenglish.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.co.nz',
#   'logo_url': 'https://img.logo.dev/wurth.co.nz?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'starkey.co.kr', 'logo_url': 'LOGO_NOT_FOUND'},
#  {'domain': 'yves-rocher.ch',
#   'logo_url': 'https://img.logo.dev/yves-rocher.ch?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'tapflo.hu',
#   'logo_url': 'https://img.logo.dev/tapflo.hu?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'lghealthjobs.org',
#   'logo_url': 'https://img.logo.dev/lghealthjobs.org?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'tapflo.at',
#   'logo_url': 'https://img.logo.dev/tapflo.at?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'overheaddooraz.com',
#   'logo_url': 'https://img.logo.dev/overheaddooraz.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'rjelinek.cl',
#   'logo_url': 'https://img.logo.dev/rjelinek.cl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'duracell.pl',
#   'logo_url': 'https://img.logo.dev/duracell.pl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'starbucks.com.gr',
#   'logo_url': 'https://img.logo.dev/starbucks.com.gr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'kia-mouscron.be',
#   'logo_url': 'https://img.logo.dev/kia-mouscron.be?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'svnnc.com',
#   'logo_url': 'https://img.logo.dev/svnnc.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'planncosteels.com',
#   'logo_url': 'https://img.logo.dev/planncosteels.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.co.uk',
#   'logo_url': 'https://img.logo.dev/wurth.co.uk?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef-mayenne.com',
#   'logo_url': 'https://img.logo.dev/medef-mayenne.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'eis.com.tr', 'logo_url': 'LOGO_NOT_FOUND'},
#  {'domain': 'rotary-club-strasbourg.org',
#   'logo_url': 'https://img.logo.dev/rotary-club-strasbourg.org?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'coffeesmith.com.sg',
#   'logo_url': 'https://img.logo.dev/coffeesmith.com.sg?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'acuraofgainesville.com',
#   'logo_url': 'https://img.logo.dev/acuraofgainesville.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'kia.pt',
#   'logo_url': 'https://img.logo.dev/kia.pt?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'chubblifefund.com.vn',
#   'logo_url': 'https://img.logo.dev/chubblifefund.com.vn?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'svndesertcommercial.com',
#   'logo_url': 'https://img.logo.dev/svndesertcommercial.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'zkteco.me',
#   'logo_url': 'https://img.logo.dev/zkteco.me?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyota-paris5.fr',
#   'logo_url': 'https://img.logo.dev/toyota-paris5.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'plameco-huizen.nl',
#   'logo_url': 'https://img.logo.dev/plameco-huizen.nl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'pakuacanada.com',
#   'logo_url': 'https://img.logo.dev/pakuacanada.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'fortprousa.com',
#   'logo_url': 'https://img.logo.dev/fortprousa.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyota-givors.fr',
#   'logo_url': 'https://img.logo.dev/toyota-givors.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'bakertilly.site',
#   'logo_url': 'https://img.logo.dev/bakertilly.site?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef-44.fr',
#   'logo_url': 'https://img.logo.dev/medef-44.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'einhell.bg',
#   'logo_url': 'https://img.logo.dev/einhell.bg?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'invisalign.co.kr',
#   'logo_url': 'https://img.logo.dev/invisalign.co.kr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'aon.hu', 'logo_url': 'LOGO_NOT_FOUND'},
#  {'domain': 'scoutaerialafrica.com',
#   'logo_url': 'https://img.logo.dev/scoutaerialafrica.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'intersport.hr',
#   'logo_url': 'https://img.logo.dev/intersport.hr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'invisalign.it',
#   'logo_url': 'https://img.logo.dev/invisalign.it?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'idealindustries.cn',
#   'logo_url': 'https://img.logo.dev/idealindustries.cn?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.lv',
#   'logo_url': 'https://img.logo.dev/wurth.lv?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'travelocarbooking.com',
#   'logo_url': 'https://img.logo.dev/travelocarbooking.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef-franche-comte.com',
#   'logo_url': 'https://img.logo.dev/medef-franche-comte.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'takeda.com.ru',
#   'logo_url': 'https://img.logo.dev/takeda.com.ru?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'einhell.dk',
#   'logo_url': 'https://img.logo.dev/einhell.dk?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'rubiomonocoat.com.pl',
#   'logo_url': 'https://img.logo.dev/rubiomonocoat.com.pl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.pe',
#   'logo_url': 'https://img.logo.dev/wurth.pe?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'bluecardagency.ru',
#   'logo_url': 'https://img.logo.dev/bluecardagency.ru?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef-pays-basque.fr',
#   'logo_url': 'https://img.logo.dev/medef-pays-basque.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'einhell.nl',
#   'logo_url': 'https://img.logo.dev/einhell.nl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'gs1.org.bo',
#   'logo_url': 'https://img.logo.dev/gs1.org.bo?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'cardif.pl',
#   'logo_url': 'https://img.logo.dev/cardif.pl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.cl',
#   'logo_url': 'https://img.logo.dev/wurth.cl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef-cote-opale.com',
#   'logo_url': 'https://img.logo.dev/medef-cote-opale.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'duracell.co.za',
#   'logo_url': 'https://img.logo.dev/duracell.co.za?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medef31.fr',
#   'logo_url': 'https://img.logo.dev/medef31.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'specialistnutrition.us',
#   'logo_url': 'https://img.logo.dev/specialistnutrition.us?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'yves-rocher.nl',
#   'logo_url': 'https://img.logo.dev/yves-rocher.nl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'solatube.si',
#   'logo_url': 'https://img.logo.dev/solatube.si?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'lamannamovingny.com', 'logo_url': 'LOGO_NOT_FOUND'},
#  {'domain': 'synlab.lt',
#   'logo_url': 'https://img.logo.dev/synlab.lt?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'yves-rocher.de',
#   'logo_url': 'https://img.logo.dev/yves-rocher.de?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'pingusenglish.vn',
#   'logo_url': 'https://img.logo.dev/pingusenglish.vn?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'sonepar.hu',
#   'logo_url': 'https://img.logo.dev/sonepar.hu?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'avonworldwide.com',
#   'logo_url': 'https://img.logo.dev/avonworldwide.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'invisalign.de',
#   'logo_url': 'https://img.logo.dev/invisalign.de?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'invisalign.ch',
#   'logo_url': 'https://img.logo.dev/invisalign.ch?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'einhell.rs',
#   'logo_url': 'https://img.logo.dev/einhell.rs?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'solatube.com.cn',
#   'logo_url': 'https://img.logo.dev/solatube.com.cn?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wuerth.bg',
#   'logo_url': 'https://img.logo.dev/wuerth.bg?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'tapflo.by',
#   'logo_url': 'https://img.logo.dev/tapflo.by?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'kelloggs.fr',
#   'logo_url': 'https://img.logo.dev/kelloggs.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.co.za',
#   'logo_url': 'https://img.logo.dev/wurth.co.za?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'pepsico.pt',
#   'logo_url': 'https://img.logo.dev/pepsico.pt?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'invisalign.ae',
#   'logo_url': 'https://img.logo.dev/invisalign.ae?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.pt',
#   'logo_url': 'https://img.logo.dev/wurth.pt?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'entergy-nuclear.com',
#   'logo_url': 'https://img.logo.dev/entergy-nuclear.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'overheaddoorsrichmond.com',
#   'logo_url': 'https://img.logo.dev/overheaddoorsrichmond.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'synlab.mk',
#   'logo_url': 'https://img.logo.dev/synlab.mk?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyota-magny.fr',
#   'logo_url': 'https://img.logo.dev/toyota-magny.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'sealy.co.kr',
#   'logo_url': 'https://img.logo.dev/sealy.co.kr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wordans.it',
#   'logo_url': 'https://img.logo.dev/wordans.it?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'medeforne.fr',
#   'logo_url': 'https://img.logo.dev/medeforne.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyotacomauto.com',
#   'logo_url': 'https://img.logo.dev/toyotacomauto.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'mitsubishi-motors.com.ar', 'logo_url': 'LOGO_NOT_FOUND'},
#  {'domain': 'peach.immo',
#   'logo_url': 'https://img.logo.dev/peach.immo?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'synlab.by',
#   'logo_url': 'https://img.logo.dev/synlab.by?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'pmsgen.com',
#   'logo_url': 'https://img.logo.dev/pmsgen.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyotacommonwealth.com',
#   'logo_url': 'https://img.logo.dev/toyotacommonwealth.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wuerth.my',
#   'logo_url': 'https://img.logo.dev/wuerth.my?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'acurahonolulu.com',
#   'logo_url': 'https://img.logo.dev/acurahonolulu.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'kynixsemiconductor.com',
#   'logo_url': 'https://img.logo.dev/kynixsemiconductor.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'diamond.co.id',
#   'logo_url': 'https://img.logo.dev/diamond.co.id?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'takedaoncology.com',
#   'logo_url': 'https://img.logo.dev/takedaoncology.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'rsm.bh',
#   'logo_url': 'https://img.logo.dev/rsm.bh?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'delreg.com',
#   'logo_url': 'https://img.logo.dev/delreg.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'rcchurch.com', 'logo_url': 'LOGO_NOT_FOUND'},
#  {'domain': 'ford.cl',
#   'logo_url': 'https://img.logo.dev/ford.cl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'fft-ps.pl',
#   'logo_url': 'https://img.logo.dev/fft-ps.pl?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'tapflo.se',
#   'logo_url': 'https://img.logo.dev/tapflo.se?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'toyota-lyonsud.fr',
#   'logo_url': 'https://img.logo.dev/toyota-lyonsud.fr?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'gs1my.org',
#   'logo_url': 'https://img.logo.dev/gs1my.org?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'wurth.sk',
#   'logo_url': 'https://img.logo.dev/wurth.sk?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'ampersand-world.com',
#   'logo_url': 'https://img.logo.dev/ampersand-world.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'portadoors.com',
#   'logo_url': 'https://img.logo.dev/portadoors.com?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'},
#  {'domain': 'solatube.pt',
#   'logo_url': 'https://img.logo.dev/solatube.pt?token=pk_YHX64SgZS5Ws1uLYAkiEJQ&fallback=404'}]

# %%
import os
import requests

def download_logos(logo_data, save_dir='logos'):

    for item in logo_data:
        domain = item['domain']
        logo_url = item['logo_url']

        if logo_url == 'NO_LOGO_FOUND':
            print(f"❌ Skipping {domain} — no logo found.")
            continue

        try:
            response = requests.get(logo_url, timeout=10)
            if response.status_code == 200:
                file_path = os.path.join(save_dir, f"{domain}.png")
                with open(file_path, 'wb') as f:
                    f.write(response.content)
                print(f"✅ Saved logo for {domain}")
            else:
                print(f"⚠️ Failed to download logo for {domain} (status {response.status_code})")
        except Exception as e:
            print(f"⚠️ Error downloading logo for {domain}: {e}")

# %%
download_logos(failed_domains)
# Out:
# ✅ Saved logo for xella-colloquium.berlin
# ✅ Saved logo for secureparkinghi.com
# ✅ Saved logo for rheine.schule
# ✅ Saved logo for ford.pl.ua
# ✅ Saved logo for adecco.cl
# ✅ Saved logo for pcllawyersfrankston.com.au
# ✅ Saved logo for wurth.com.uy
# ✅ Saved logo for renaultchiva.com
# ✅ Saved logo for medef-artois.fr
# ✅ Saved logo for medef-bearnetsoule.com
# ❌ Skipping chicco.pl — no logo found.
# ✅ Saved logo for rotaryclubofessex.com
# ✅ Saved logo for toofacedcosmetics.jp
# ✅ Saved logo for rubiomonocoat.com.au
# ✅ Saved logo for spitexaadorf.ch
# ✅ Saved logo for metlife.co.kr
# ✅ Saved logo for toyotafocsani.ro
# ✅ Saved logo for secureparking.co.id
# ✅ Saved logo for mazda-angola-autozuid.com
# ✅ Saved logo for nikonschool.de
# ✅ Saved logo for toyota-annecy.fr
# ✅ Saved logo for toyota-rillieux.fr
# ❌ Skipping chicco.ru — no logo found.
# ✅ Saved logo for subaru-bd.com
# ✅ Saved logo for toyotaortakoy.com.tr
# ✅ Saved logo for mazda-uae.com
# ✅ Saved logo for propertyfinder.com
# ❌ Skipping pingusenglishbd.com — no logo found.
# ✅ Saved logo for aamcovinelandnj.com
# ✅ Saved logo for wurth.lk
# ✅ Saved logo for tgmresearch.vn
# ✅ Saved logo for intersport.si
# ✅ Saved logo for santander.pt
# ✅ Saved logo for suttontools.co.nz
# ✅ Saved logo for renault.pe
# ✅ Saved logo for wurth.com.vn
# ✅ Saved logo for synlab.hr
# ✅ Saved logo for toyotaconstanta.ro
# ✅ Saved logo for pkffinconta.ro
# ✅ Saved logo for mcvitiesindia.com
# ✅ Saved logo for pingusenglish.ac.th
# ✅ Saved logo for medef-essonne.org
# ✅ Saved logo for wordans.de
# ✅ Saved logo for toyotabucurestinord.ro
# ✅ Saved logo for wurth.hu
# ✅ Saved logo for adeccome.com
# ✅ Saved logo for trisa.bg
# ✅ Saved logo for nestle.ro
# ✅ Saved logo for shahshalalfood.com
# ✅ Saved logo for invisalign.co.il
# ✅ Saved logo for linexswfl.com
# ✅ Saved logo for honda.com.ng
# ✅ Saved logo for tapflo.co.za
# ✅ Saved logo for whirlpool.com.hk
# ✅ Saved logo for metlife.com.cy
# ✅ Saved logo for carlsjr.com.my
# ✅ Saved logo for medef-beziers.fr
# ✅ Saved logo for hondaheritagecenter.com
# ✅ Saved logo for mazdalanka.lk
# ✅ Saved logo for veka.com.sg
# ✅ Saved logo for captrain.pl
# ✅ Saved logo for nelsonlabsbozeman.com
# ✅ Saved logo for sitech-ohio.com
# ✅ Saved logo for sanlorenzo.com.pe
# ✅ Saved logo for kiamotors.com.kh
# ✅ Saved logo for mapfre.com.py
# ✅ Saved logo for medef-aude.com
# ✅ Saved logo for duracell.in
# ❌ Skipping allianzportugal.pt — no logo found.
# ✅ Saved logo for seqens.fi
# ✅ Saved logo for toyotaploiesti.ro
# ✅ Saved logo for premiumproperties.com
# ✅ Saved logo for yves-rocher.at
# ✅ Saved logo for tapflo.kz
# ✅ Saved logo for duracell.com.tr
# ✅ Saved logo for yves-rocher.se
# ✅ Saved logo for ikea.com.tw
# ❌ Skipping oaklandwoodfloors.net — no logo found.
# ✅ Saved logo for decathlon.com.br
# ✅ Saved logo for davesmithfordonline.net
# ✅ Saved logo for venturelightingme.com
# ✅ Saved logo for tupperware.gr
# ✅ Saved logo for toyota-corbeil.fr
# ✅ Saved logo for toyota-montluel.fr
# ✅ Saved logo for mazda.com.kh
# ✅ Saved logo for toyota-chartres.fr
# ✅ Saved logo for wuerth.com.ph
# ✅ Saved logo for thebodyshop.com.br
# ✅ Saved logo for wurth.co.ke
# ✅ Saved logo for yvesrocher.com.tr
# ✅ Saved logo for medef79.fr
# ❌ Skipping renaultpachuca.com.mx — no logo found.
# ✅ Saved logo for invisalign.co.uk
# ✅ Saved logo for adecco.ie
# ✅ Saved logo for overheaddoorcompanyjackson.com
# ✅ Saved logo for mapfre.com.uy
# ✅ Saved logo for medef-nouvelle-aquitaine.fr
# ✅ Saved logo for subaru.mt
# ✅ Saved logo for medef-anjou.fr
# ✅ Saved logo for aamco-corpuschristi.com
# ✅ Saved logo for path-solutions.com
# ✅ Saved logo for pixibeauty.co.uk
# ✅ Saved logo for invisalign.fr
# ✅ Saved logo for takeda.nl
# ✅ Saved logo for pingusenglish.com
# ✅ Saved logo for wurth.co.nz
# ❌ Skipping starkey.co.kr — no logo found.
# ✅ Saved logo for yves-rocher.ch
# ✅ Saved logo for tapflo.hu
# ✅ Saved logo for lghealthjobs.org
# ✅ Saved logo for tapflo.at
# ✅ Saved logo for overheaddooraz.com
# ✅ Saved logo for rjelinek.cl
# ✅ Saved logo for duracell.pl
# ✅ Saved logo for starbucks.com.gr
# ✅ Saved logo for kia-mouscron.be
# ✅ Saved logo for svnnc.com
# ✅ Saved logo for planncosteels.com
# ✅ Saved logo for wurth.co.uk
# ✅ Saved logo for medef-mayenne.com
# ❌ Skipping eis.com.tr — no logo found.
# ✅ Saved logo for rotary-club-strasbourg.org
# ✅ Saved logo for coffeesmith.com.sg
# ✅ Saved logo for acuraofgainesville.com
# ✅ Saved logo for kia.pt
# ✅ Saved logo for chubblifefund.com.vn
# ✅ Saved logo for svndesertcommercial.com
# ✅ Saved logo for zkteco.me
# ✅ Saved logo for toyota-paris5.fr
# ✅ Saved logo for plameco-huizen.nl
# ✅ Saved logo for pakuacanada.com
# ✅ Saved logo for fortprousa.com
# ✅ Saved logo for toyota-givors.fr
# ✅ Saved logo for bakertilly.site
# ✅ Saved logo for medef-44.fr
# ✅ Saved logo for einhell.bg
# ✅ Saved logo for invisalign.co.kr
# ❌ Skipping aon.hu — no logo found.
# ✅ Saved logo for scoutaerialafrica.com
# ✅ Saved logo for intersport.hr
# ✅ Saved logo for invisalign.it
# ✅ Saved logo for idealindustries.cn
# ✅ Saved logo for wurth.lv
# ✅ Saved logo for travelocarbooking.com
# ✅ Saved logo for medef-franche-comte.com
# ✅ Saved logo for takeda.com.ru
# ✅ Saved logo for einhell.dk
# ✅ Saved logo for rubiomonocoat.com.pl
# ✅ Saved logo for wurth.pe
# ✅ Saved logo for bluecardagency.ru
# ✅ Saved logo for medef-pays-basque.fr
# ✅ Saved logo for einhell.nl
# ✅ Saved logo for gs1.org.bo
# ✅ Saved logo for cardif.pl
# ✅ Saved logo for wurth.cl
# ✅ Saved logo for medef-cote-opale.com
# ✅ Saved logo for duracell.co.za
# ✅ Saved logo for medef31.fr
# ✅ Saved logo for specialistnutrition.us
# ✅ Saved logo for yves-rocher.nl
# ✅ Saved logo for solatube.si
# ❌ Skipping lamannamovingny.com — no logo found.
# ✅ Saved logo for synlab.lt
# ✅ Saved logo for yves-rocher.de
# ✅ Saved logo for pingusenglish.vn
# ✅ Saved logo for sonepar.hu
# ✅ Saved logo for avonworldwide.com
# ✅ Saved logo for invisalign.de
# ✅ Saved logo for invisalign.ch
# ✅ Saved logo for einhell.rs
# ✅ Saved logo for solatube.com.cn
# ✅ Saved logo for wuerth.bg
# ✅ Saved logo for tapflo.by
# ✅ Saved logo for kelloggs.fr
# ✅ Saved logo for wurth.co.za
# ✅ Saved logo for pepsico.pt
# ✅ Saved logo for invisalign.ae
# ✅ Saved logo for wurth.pt
# ✅ Saved logo for entergy-nuclear.com
# ✅ Saved logo for overheaddoorsrichmond.com
# ✅ Saved logo for synlab.mk
# ✅ Saved logo for toyota-magny.fr
# ✅ Saved logo for sealy.co.kr
# ✅ Saved logo for wordans.it
# ✅ Saved logo for medeforne.fr
# ✅ Saved logo for toyotacomauto.com
# ❌ Skipping mitsubishi-motors.com.ar — no logo found.
# ✅ Saved logo for peach.immo
# ✅ Saved logo for synlab.by
# ✅ Saved logo for pmsgen.com
# ✅ Saved logo for toyotacommonwealth.com
# ✅ Saved logo for wuerth.my
# ✅ Saved logo for acurahonolulu.com
# ✅ Saved logo for kynixsemiconductor.com
# ✅ Saved logo for diamond.co.id
# ✅ Saved logo for takedaoncology.com
# ✅ Saved logo for rsm.bh
# ✅ Saved logo for delreg.com
# ❌ Skipping rcchurch.com — no logo found.
# ✅ Saved logo for ford.cl
# ✅ Saved logo for fft-ps.pl
# ✅ Saved logo for tapflo.se
# ✅ Saved logo for toyota-lyonsud.fr
# ✅ Saved logo for gs1my.org
# ✅ Saved logo for wurth.sk
# ✅ Saved logo for ampersand-world.com
# ✅ Saved logo for portadoors.com
# ✅ Saved logo for solatube.pt

# %%
totally_failed_domains = [entry for entry in failed_domains if entry['logo_url'] == 'NO_LOGO_FOUND']

# %%
totally_failed_domains
# Out:
# []

# %% [markdown]
# ## Convert all image formats to something PIL can handle

# %%
import os
import imghdr
import io
import cairosvg
from PIL import Image

def is_avif(path):
    try:
        with open(path, "rb") as f:
            return b"ftypavif" in f.read(32)
    except:
        return False

def load_image(path):
    ext = os.path.splitext(path)[1].lower()

    try:
        if ext == '.svg':
            png_data = cairosvg.svg2png(url=path)
            return Image.open(io.BytesIO(png_data)).convert("RGB")

        elif ext in ['.jpg', '.jpeg', '.png', '.webp', '.avif']:
            return Image.open(path).convert("RGB")

        elif ext == '.img':
            if is_avif(path):  # use your header check
                try:
                    return Image.open(path).convert("RGB")
                except Exception as e:
                    print(f"⚠️ Skipping unreadable AVIF: {path} — {e}")
                    return None
            else:
                real_ext = imghdr.what(path)
                if real_ext in ['jpeg', 'png', 'webp']:
                    return Image.open(path).convert("RGB")
                else:
                    print(f"⚠️ Skipping unknown .img: {path} (detected: {real_ext})")
                    return None

        else:
            print(f"⚠️ Skipping unsupported extension: {path}")
            return None

    except Exception as e:
        print(f"❌ Skipping unreadable file: {path} — Reason: {e}")
        return None

# %% [markdown]
# ## Logo Similarity

# %%
import torch
import hnswlib
import numpy as np
import networkx as nx
import networkx.algorithms.components.connected as nx_conn
from tqdm import tqdm
from transformers import AutoProcessor, AutoModel
import pillow_avif
from PIL import Image
import community as community_louvain

# %%
from PIL import Image, ImageOps

def pad_to_square(image, fill=(255, 255, 255)):
    w, h = image.size
    max_dim = max(w, h)
    delta_w = max_dim - w
    delta_h = max_dim - h
    padding = (delta_w // 2, delta_h // 2, delta_w - delta_w // 2, delta_h - delta_h // 2)
    return ImageOps.expand(image, padding, fill=fill)

# %%
from transformers import AutoProcessor, AutoModel
import torch
import numpy as np
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
processor = AutoProcessor.from_pretrained("facebook/dinov2-base")
model = AutoModel.from_pretrained("facebook/dinov2-base").eval().to(device)

# Lock processor to 224x224 resolution, disable cropping
processor.size = {"height": 224, "width": 224}
processor.do_center_crop = False

def extract_features_with_padding(image_paths, domains, batch_size=32):
    all_embeddings = []
    valid_domains = []

    with torch.inference_mode():
        for i in tqdm(range(0, len(image_paths), batch_size), desc="Extracting features"):
            batch_imgs = []
            batch_domains = []

            for p, domain in zip(image_paths[i:i+batch_size], domains[i:i+batch_size]):
                img = load_image(p)
                if img is None:
                    continue
                img = pad_to_square(img)
                batch_imgs.append(img)
                batch_domains.append(domain)

            if not batch_imgs:
                continue

            inputs = processor(images=batch_imgs, return_tensors="pt").to(device)
            outputs = model(**inputs).last_hidden_state.mean(dim=1)
            all_embeddings.append(outputs.cpu().numpy())
            valid_domains.extend(batch_domains)

    return np.vstack(all_embeddings), valid_domains
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %%
import hnswlib

def build_hnsw_index(embeddings, ef=100, ef_construction=200, M=64, save_path=None):
    dim = embeddings.shape[1]
    index = hnswlib.Index(space='l2', dim=dim)
    index.init_index(max_elements=len(embeddings), ef_construction=ef_construction, M=M)
    index.add_items(embeddings)
    index.set_ef(ef)

    if save_path:
        index.save_index(save_path)
    
    return index

# %%
import igraph as ig
import leidenalg

def build_similarity_graph(index, embeddings, k=10, threshold=0.75):
    labels, distances = index.knn_query(embeddings, k=k)
    G = nx.Graph()

    for i in range(len(embeddings)):
        for j, neighbor in enumerate(labels[i]):
            if i != neighbor:
                similarity = 1 - distances[i][j]
                if similarity >= threshold:
                    G.add_edge(i, neighbor, weight=similarity)

    return G

def graph_to_igraph(G_nx):
    """Convert NetworkX graph to igraph."""
    mapping = {node: idx for idx, node in enumerate(G_nx.nodes())}
    reverse_mapping = {idx: node for node, idx in mapping.items()}
    edges = [(mapping[u], mapping[v]) for u, v in G_nx.edges()]
    
    G_ig = ig.Graph(edges=edges, directed=False)
    return G_ig, reverse_mapping

def cluster_with_leiden(G_nx):
    G_ig, reverse_map = graph_to_igraph(G_nx)
    partition = leidenalg.find_partition(G_ig, leidenalg.ModularityVertexPartition)
    
    clusters = {}
    for cluster_id, nodes in enumerate(partition):
        clusters[cluster_id] = [reverse_map[n] for n in nodes]
    
    return clusters

# %%
def split_clusters(G):
    components = list(nx_conn.connected_components(G))
    final_clusters = []
    unique_logos = []

    for comp in components:
        if len(comp) > 1:
            final_clusters.append(list(comp))
        else:
            unique_logos.append(list(comp)[0])
    
    return final_clusters, unique_logos

# %%
def cluster_indices_to_domains(cluster_dict, domains):
    cluster_domains = {}
    for cluster_id, logo_indices in cluster_dict.items():
        cluster_domains[cluster_id] = [domains[i] for i in logo_indices]
    return cluster_domains

# %%
import os

def get_logo_paths_from_folder(folder):
    supported_exts = ['.jpg', '.jpeg', '.png', '.webp', '.svg', '.img']
    logo_paths = []
    domains = []

    for filename in os.listdir(folder):
        ext = os.path.splitext(filename)[1].lower()
        if ext in supported_exts:
            domain = os.path.splitext(filename)[0]  # remove extension
            path = os.path.join(folder, filename)
            logo_paths.append(path)
            domains.append(domain)

    return logo_paths, domains

# %%
import csv

def save_clusters_to_csv(cluster_dict, domains, output_file="clusters.csv"):
    with open(output_file, mode="w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["cluster_id", "domain"])
        for cluster_id, indices in cluster_dict.items():
            for idx in indices:
                writer.writerow([cluster_id, domains[idx]])
    print(f"✅ Clusters saved to {output_file}")

# %%
# Assuming logo_paths = list of file paths (PIL-compatible)
logo_paths, domains = get_logo_paths_from_folder("logos")

# Extract features with logo integrity preserved and standard 224x224
embeddings, valid_domains = extract_features_with_padding(logo_paths, domains, batch_size=32)

# 3. Build and save HNSW index
index = build_hnsw_index(embeddings, save_path="hnsw_index.bin")

# 4. Build graph and cluster
G = build_similarity_graph(index, embeddings, k=3, threshold=0.9)
clusters_dict = cluster_with_leiden(G)
final_clusters, unique_logos = split_clusters(G)

# 5. Map cluster indices to domain names
domain_clusters = cluster_indices_to_domains(clusters_dict, valid_domains)
save_clusters_to_csv(clusters_dict, valid_domains, output_file="clusters.csv")

# 6. Print cluster summaries
print(f"\nTotal clusters with similar logos: {len(final_clusters)}")
print(f"Total unique logos (singletons): {len(unique_logos)}\n")

for cluster_id, domain_list in domain_clusters.items():
    if len(domain_list) > 1:
        print(f"Cluster {cluster_id} ({len(domain_list)} logos): {set(domain_list)}")
# Out:
# Extracting features:   0%|          | 0/107 [00:00<?, ?it/s]c:\Users\filip\Desktop\Veridion\1. Logo Similarity\logo_venv\lib\site-packages\PIL\Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Extracting features:  21%|██        | 22/107 [00:07<00:28,  3.00it/s]
# ❌ Skipping unreadable file: logos\buydaikin.ro.png — Reason: cannot identify image file 'C:\\Users\\filip\\Desktop\\Veridion\\1. Logo Similarity\\logos\\buydaikin.ro.png'
# Extracting features:  65%|██████▌   | 70/107 [00:25<00:10,  3.53it/s]
# ❌ Skipping unreadable file: logos\nepaltrust.gov.np.png — Reason: cannot identify image file 'C:\\Users\\filip\\Desktop\\Veridion\\1. Logo Similarity\\logos\\nepaltrust.gov.np.png'
# Extracting features:  69%|██████▉   | 74/107 [00:26<00:09,  3.54it/s]
# ❌ Skipping unreadable file: logos\papajohns.co.nl.png — Reason: cannot identify image file 'C:\\Users\\filip\\Desktop\\Veridion\\1. Logo Similarity\\logos\\papajohns.co.nl.png'
# ❌ Skipping unreadable file: logos\papajohns.com.pk.png — Reason: cannot identify image file 'C:\\Users\\filip\\Desktop\\Veridion\\1. Logo Similarity\\logos\\papajohns.com.pk.png'
# Extracting features:  70%|███████   | 75/107 [00:26<00:08,  3.68it/s]
# ❌ Skipping unreadable file: logos\papajohns.ma.png — Reason: cannot identify image file 'C:\\Users\\filip\\Desktop\\Veridion\\1. Logo Similarity\\logos\\papajohns.ma.png'
# ❌ Skipping unreadable file: logos\papajohnsquebec.ca.png — Reason: cannot identify image file 'C:\\Users\\filip\\Desktop\\Veridion\\1. Logo Similarity\\logos\\papajohnsquebec.ca.png'
# Extracting features:  88%|████████▊ | 94/107 [00:37<00:08,  1.56it/s]
# ❌ Skipping unreadable file: logos\tbwaalif.com.svg — Reason: EntitiesForbidden(name='ns_extend', system_id=None, public_id=None)
# Extracting features: 100%|██████████| 107/107 [00:43<00:00,  2.45it/s]
# ✅ Clusters saved to clusters.csv
#
# Total clusters with similar logos: 286
# Total unique logos (singletons): 0
#
# Cluster 47 (7 logos): {'ibc-solar.es', 'ibc-solar.pl', 'ibc-solar.it', 'ibc-solar.cz', 'ibc-solar.co.za', 'ibc-solar.nl', 'ibc-solar.jp'}
# Cluster 48 (6 logos): {'entergy-louisiana.com', 'entergy-arkansas.com', 'entergy-mississippi.com', 'entergy-texas.com', 'entergy-neworleans.com', 'entergynewsroom.com'}
# Cluster 49 (6 logos): {'toyota-montluel.fr', 'toyota-lyonsud.fr', 'toyota-rillieux.fr', 'toyota-givors.fr', 'toyota-annecy.fr', 'toyota-paris5.fr'}
# Cluster 50 (6 logos): {'allianz-kuhlemann.de', 'allianz-rose.info', 'allianz-sebastiankoch.de', 'allianz-genc.de', 'allianz-peev.de', 'sekulin-allianz.de'}
# Cluster 51 (6 logos): {'modshair-koeln-lindenthal.de', 'modshair-koeln-city.de', 'modshair-hannover.de', 'modshair-bielefeld.de', 'modshair-braunschweig.de', 'modshair-stuttgart.de'}
# Cluster 52 (6 logos): {'orange-bissau.com', 'orange.cm', 'orange.cd', 'orange.com.lr', 'orange.co.bw', 'orange.md'}
# Cluster 53 (6 logos): {'budget.co.ao', 'budgetqatar.com', 'budget.bg', 'budgetinternational.com', 'budget-egypt.com', 'budgetoman.com'}
# Cluster 54 (6 logos): {'pragroup.de', 'pragroup.se', 'pragroup.at', 'pragroup.no', 'pragroup.pl', 'pragroup.fi'}
# Cluster 55 (6 logos): {'ccusa.hu', 'ccusa.co.nz', 'ccusa.cz', 'ccusa.co.uk', 'ccusa.com.au', 'ccusa.ca'}
# Cluster 56 (6 logos): {'europa-union-sachsen-anhalt.de', 'europa-union-diepholz.de', 'europa-union-bremen.de', 'europa-union-niedersachsen.de', 'europa-union-havelland.de', 'europa-union-sachsen.de'}
# Cluster 57 (6 logos): {'misterwhat.pt', 'misterwhat-au.com', 'misterwhat.pl', 'misterwhat.com.br', 'misterwhat.de', 'misterwhat.nl'}
# Cluster 58 (6 logos): {'mitsubishielectric.in', 'mitsubishielectric.se', 'mitsubishielectric.com.cn', 'mitsubishielevator.co.kr', 'mitsubishielectric.com.sg', 'mitsubishielectric-printing.com'}
# Cluster 59 (6 logos): {'wurth-international.com', 'wuerth.com.kh', 'wuerth-gruppe.ch', 'wurth.ua', 'wurth.ae', 'wurthcanarias.es'}
# Cluster 60 (6 logos): {'menicon.nl', 'menicon.es', 'menicon.de', 'menicon.co.uk', 'meniconamerica.com', 'menicon.fr'}
# Cluster 61 (6 logos): {'boschautoparts.com', 'bosch-pt.com.cn', 'boschtools.com', 'boschautopartes.mx', 'bosch-pt.co.in', 'bosch-pt.com.my'}
# Cluster 62 (6 logos): {'funiber.ci', 'funiber.sn', 'funiber.ml', 'funiber.fr', 'funiber.ma', 'funiber.cm'}
# Cluster 63 (6 logos): {'bizfilings.com', 'wolterskluwer.com.my', 'medknow.com', 'annotext.de', 'wolterskluwer.dk', 'genya.it'}
# Cluster 64 (6 logos): {'holidayland-sanktwendel.de', 'holidayland-bruchkoebel.de', 'holidayland-reisebuero-stuppert.de', 'holidayland-dorfen.de', 'holidayland-roedermark.de', 'holidayland-friedrichshafen.de'}
# Cluster 65 (6 logos): {'shopee.com.co', 'shopee.in', 'shopee.co.th', 'shopee.com.my', 'shopee.com.mx', 'shopee.vn'}
# Cluster 66 (6 logos): {'veolia.pl', 'veolia.es', 'veolia.com.ru', 'veolia.fi', 'veolia.jp', 'veolia.in'}
# Cluster 67 (6 logos): {'aeccglobal.lk', 'aeccglobal.my', 'aeccglobal.sg', 'aeccglobal.ng', 'aeccglobal.com.bd', 'aeccglobal.vn'}
# Cluster 68 (6 logos): {'kumon.com.uy', 'kumon.cl', 'kumon.com.ar', 'kumon.com.co', 'kumon.com.pe', 'kumon.com.bo'}
# Cluster 69 (6 logos): {'nordicpharma.es', 'nordicpharma.nl', 'nordicpharma.co.uk', 'nordicpharma.it', 'nordicpharma.fr', 'nordicpharma.de'}
# Cluster 70 (6 logos): {'saint-gobain-solutions.nl', 'saint-gobain.com.co', 'saint-gobain.bg', 'saint-gobain.al', 'saint-gobain-glass.es', 'saint-gobain.mk'}
# Cluster 71 (6 logos): {'toyota-buchreiter-eisenstadt.at', 'toyota-innviertel.at', 'toyota-ulrichshofer.at', 'toyota-handler.at', 'toyota-bauer.at', 'toyota-niederberger.at'}
# Cluster 72 (5 logos): {'ebay.fr', 'ebay.pl', 'ebay.it', 'ebay.com.tw', 'ebay.com.hk'}
# Cluster 73 (5 logos): {'equans.cz', 'equans.cl', 'equans.lu', 'equansservices.com', 'equans.co'}
# Cluster 74 (5 logos): {'mapfre.pr', 'mapfre.com.gt', 'mapfre.com.sv', 'mapfre.com.ni', 'mapfre.com.ve'}
# Cluster 75 (5 logos): {'pirtek.ie', 'pirtek.be', 'pirtek.se', 'pirtek.de', 'pirtek.at'}
# Cluster 76 (5 logos): {'titancontainers.us', 'titancontainers.co.uk', 'titancontainers.dk', 'titancontainers.ie', 'titancontainers.at'}
# Cluster 77 (5 logos): {'fmlogistic.cz', 'fmlogistic.sk', 'fmlogistic.com.ua', 'fmlogistic.com.br', 'fmlogistic.ro'}
# Cluster 78 (5 logos): {'nutriciavoorjou.nl', 'nutricia.nl', 'nutricia.de', 'nutriciababy.be', 'nutricia.be'}
# Cluster 79 (5 logos): {'pepsico.com.pk', 'pepsico.co.it', 'pepsico.com.br', 'pepsico.com.tr', 'pepsico.com.co'}
# Cluster 80 (5 logos): {'vkf-renzel.nl', 'vkf-renzel.ro', 'vkf-renzel.co.uk', 'vkf-renzel.fr', 'vkf-renzel.com.tr'}
# Cluster 81 (5 logos): {'ymcawaycross.com', 'ymcaup.org', 'ymcatoledo.org', 'ymca-ywca.org', 'ymcaswv.com'}
# Cluster 82 (5 logos): {'amway.fr', 'amway.at', 'amway.it', 'amway.ch', 'amway.de'}
# Cluster 83 (5 logos): {'repsol.pe', 'repsolresourcesuk.com', 'repsol.fr', 'repsol.us', 'repsol.no'}
# Cluster 84 (5 logos): {'thebodyshop.fi', 'thebodyshop.si', 'thebodyshop.lt', 'thebodyshop.lv', 'thebodyshop.ee'}
# Cluster 85 (5 logos): {'toyota.com.kh', 'toyota.com.np', 'toyota.bo', 'toyota.com.co', 'toyota.com.la'}
# Cluster 86 (5 logos): {'lidl.ee', 'lidl.lu', 'lidl.lv', 'lidl.com.cy', 'lidl.lt'}
# Cluster 87 (5 logos): {'mtn.zm', 'mtn.ng', 'mtn.co.sz', 'mtn.com.af', 'mtn.com.gh'}
# Cluster 88 (5 logos): {'tapflo.it', 'tapflo.hu', 'tapflo.at', 'tapflo.kz', 'tapflo.co.za'}
# Cluster 89 (5 logos): {'zkteco.com.bd', 'zkteco-ao.com', 'zkteco.com.pk', 'zkteco.in', 'zkteco.vn'}
# Cluster 90 (4 logos): {'adecco.cl', 'adeccome.com', 'adecco.com.sg', 'adecco.ie'}
# Cluster 91 (4 logos): {'adeccojapanese.asia', 'adecco.rs', 'adecco.com.vn', 'adecco.co.th'}
# Cluster 92 (4 logos): {'algeco.pt', 'algeco.si', 'algeco.ro', 'algeco.at'}
# Cluster 93 (4 logos): {'aonsolutions.com.tr', 'aonsolutions.com.cy', 'aonsolutions.gr', 'aonhewitt.com.cy'}
# Cluster 94 (4 logos): {'veoliawatertechnologies.fi', 'veoliawatertechnologies.fr', 'biothanesolutions.com', 'veoliawatertechnologies.es'}
# Cluster 95 (4 logos): {'crif.com.tr', 'crif.hk', 'crif.ch', 'crif.pl'}
# Cluster 96 (4 logos): {'duracell.fr', 'duracell.es', 'duracell-me.com', 'duracell.it'}
# Cluster 97 (4 logos): {'esseskincare.se', 'esseskincare.no', 'esseskincare.nl', 'esseskincare.sg'}
# Cluster 98 (4 logos): {'ford.dn.ua', 'ford.vn.ua', 'ford.if.ua', 'ford.te.ua'}
# Cluster 99 (4 logos): {'hansa-flex.co.uk', 'hansa-flex.at', 'hansa-flex.be', 'hansa-flex.us'}
# Cluster 100 (4 logos): {'kawasaki-seufert.de', 'kawasaki-center-koeln.de', 'kawasaki-herzog.de', 'kawasaki-magdeburg.de'}
# Cluster 101 (4 logos): {'kiajc.com', 'kiaofdaphne.com', 'kiamarin.com', 'kiaofgrandblanc.com'}
# Cluster 102 (4 logos): {'lindegas.hu', 'linde-electronics.com', 'linde.co.th', 'linde-gas.sk'}
# Cluster 103 (4 logos): {'linexofstlouismo.com', 'linexofchickasha.com', 'linexofjoliet.com', 'linexofwilliston.com'}
# Cluster 104 (4 logos): {'manpowergroup.gr', 'manpowergroup.se', 'manpower.co.za', 'manpowergroup.no'}
# Cluster 105 (4 logos): {'mazda.co.me', 'mazda.al', 'mazda.bg', 'mazda.gr'}
# Cluster 106 (4 logos): {'mazda.com.tr', 'mazda.si', 'mazda.es', 'mazda.hu'}
# Cluster 107 (4 logos): {'meggle-group.com', 'meggle.co.jp', 'meggle-cheese.com', 'meggle-bakery.com'}
# Cluster 108 (4 logos): {'mercyships.fr', 'mercyships.ch', 'mercyships.dk', 'mercyships.de'}
# Cluster 109 (4 logos): {'msd-animal-health.be', 'msd-animal-health.pl', 'msd-animal-health.com.au', 'msd-animal-health.dk'}
# Cluster 110 (4 logos): {'msmode.lu', 'msmode.de', 'msmode.es', 'msmode.fr'}
# Cluster 111 (4 logos): {'narscosmetics.co.uk', 'narscosmetics.fr', 'narscosmetics.es', 'narscosmetics.de'}
# Cluster 112 (4 logos): {'nikon.co.th', 'nikon-mea.com', 'nikon.com.sg', 'nikon.com.hk'}
# Cluster 113 (4 logos): {'nissanofopelousas.com', 'nissanattheavenues.com', 'nissanmiddletownny.com', 'nissanoflebanonnh.com'}
# Cluster 114 (4 logos): {'nobleprog.co.th', 'nobleprog.ro', 'nobleprog.com.ng', 'nobleprog.es'}
# Cluster 115 (4 logos): {'overheaddoorkalamazoo.com', 'overheaddoorcompanyjackson.com', 'overheaddoorfayetteville.com', 'overheaddoorsrichmond.com'}
# Cluster 116 (4 logos): {'pingusenglish.ps', 'pingusenglish.ee', 'pingusenglish.com.cy', 'pingusenglish.my'}
# Cluster 117 (4 logos): {'rsmthailand.com', 'rsmrecruitment.com', 'rsm.lu', 'rsmpoland.pl'}
# Cluster 118 (4 logos): {'santillana.com.co', 'santillana.com.ec', 'santillana.com.ar', 'santillana.com.pa'}
# Cluster 119 (4 logos): {'solatubescotland.co.uk', 'solatube.co.uk', 'solatube.no', 'solatube.se'}
# Cluster 120 (4 logos): {'subaruqatar.com', 'subaru.com.pa', 'subaru.com.np', 'subaru.com.gt'}
# Cluster 121 (4 logos): {'zalando.be', 'zalando.dk', 'zalando.at', 'zalando.ch'}
# Cluster 122 (4 logos): {'zalando.no', 'zalando.pl', 'zalando.ee', 'zalando.nl'}
# Cluster 123 (3 logos): {'aamcocollegestationtx.com', 'aamcokansascitysouth.com', 'aamcoelpaso-east.com'}
# Cluster 124 (3 logos): {'amnesty.org.ph', 'amnesty.lu', 'amnesty.org.ng'}
# Cluster 125 (3 logos): {'atalian.rs', 'atalian.sk', 'atalian.pl'}
# Cluster 126 (3 logos): {'bakertilly.uy', 'bakertillymapema.se', 'bakertillylb.com'}
# Cluster 127 (3 logos): {'benu.lt', 'benu.lv', 'benu.ee'}
# Cluster 128 (3 logos): {'besins-healthcare.se', 'besins-healthcare.com.mx', 'besins-healthcare.nl'}
# Cluster 129 (3 logos): {'bosch-climate.com.tr', 'bosch-homecomfort.com', 'bosch-homecomfortgroup.com'}
# Cluster 130 (3 logos): {'brother.com.pe', 'brother.com.mx', 'brother.com.br'}
# Cluster 131 (3 logos): {'ccusa.sk', 'ccusa.co.za', 'ccusa.nl'}
# Cluster 132 (3 logos): {'daikinchemicals.co.th', 'daikinchemicals.com', 'daikin-korea.co.kr'}
# Cluster 133 (3 logos): {'enterpriserentacar.bg', 'enterprise.se', 'enterpriserentacar.pl'}
# Cluster 134 (3 logos): {'experian.in', 'experian.com.hk', 'experian.com.my'}
# Cluster 135 (3 logos): {'flashbay.co.nz', 'flashbay.ca', 'flashbay.com.my'}
# Cluster 136 (3 logos): {'fmlogistic.it', 'fmlogistic.es', 'fmlogistic.pl'}
# Cluster 137 (3 logos): {'freseniuskidneycare.au', 'freseniuskidneycare.ph', 'freseniuskidneycare.asia'}
# Cluster 138 (3 logos): {'grantthornton.az', 'grantthornton.do', 'grantthornton.com.ve'}
# Cluster 139 (3 logos): {'grantthornton.ci', 'grantthornton.bg', 'grantthornton.com.sv'}
# Cluster 140 (3 logos): {'greatplacetowork.com.tr', 'greatplacetowork.ch', 'greatplacetowork.at'}
# Cluster 141 (3 logos): {'gulfcombustibles.com', 'gulf.com.mk', 'gulf.no'}
# Cluster 142 (3 logos): {'holidayland-durmersheim.de', 'holidayland-pohlheim.de', 'holidayland-wunstorf.de'}
# Cluster 143 (3 logos): {'honda.com.bd', 'honda.com.ng', 'honda.cl'}
# Cluster 144 (3 logos): {'inductotherm.com.au', 'inductotherm.ca', 'inductotherm.co.kr'}
# Cluster 145 (3 logos): {'intersport.hu', 'intersport.cz', 'intersport.sk'}
# Cluster 146 (3 logos): {'isover.sk', 'isover.de', 'isover.at'}
# Cluster 147 (3 logos): {'isover.com.br', 'isover.be', 'isover.se'}
# Cluster 148 (3 logos): {'isover.bg', 'isover.lv', 'isover.ua'}
# Cluster 149 (3 logos): {'kia-asc.ru', 'kia-chita.ru', 'kia-crimea.ru'}
# Cluster 150 (3 logos): {'kiacowansville.com', 'mazdademagog.com', 'mazdadesherbrooke.com'}
# Cluster 151 (3 logos): {'linde-gas.ee', 'linde-gas.lt', 'linde-gas.lv'}
# Cluster 152 (3 logos): {'mateco.nl', 'mateco.ro', 'mateco.bg'}
# Cluster 153 (3 logos): {'mazda.lv', 'mazda.lt', 'mazda.fi'}
# Cluster 154 (3 logos): {'mazdaofconshohocken.com', 'mazdaofpottstown.com', 'mazdaofspartanburg.com'}
# Cluster 155 (3 logos): {'mcdonalds.ma', 'mcdonalds.com.jo', 'mcdonalds.md'}
# Cluster 156 (3 logos): {'meggle-foodingredients.de', 'meggle.de', 'meggle.it'}
# Cluster 157 (3 logos): {'nestle.ro', 'nestle-caribbean.com', 'nestle.co.kr'}
# Cluster 158 (3 logos): {'nestle.com.uy', 'nestle.ba', 'nestle.ua'}
# Cluster 159 (3 logos): {'pearsonclinical.com.au', 'pearsonclinical.ca', 'pearsonclinical.co.uk'}
# Cluster 160 (3 logos): {'renault-tessenderlo.be', 'renaultvercammen.be', 'renault-fama.be'}
# Cluster 161 (3 logos): {'santanderconsumer.se', 'santanderconsumer.fi', 'santanderconsumer.no'}
# Cluster 162 (3 logos): {'shimadzu.com.br', 'shimadzu-la.com', 'shimadzu.co.kr'}
# Cluster 163 (3 logos): {'sitechnw.com', 'sitechnorthwest.com', 'sitech-ws.com'}
# Cluster 164 (3 logos): {'skoda-clermontferrand.fr', 'skoda-nancy.fr', 'skoda-metz.fr'}
# Cluster 165 (3 logos): {'starkey.com.br', 'starkey.co.uk', 'starkey.com.co'}
# Cluster 166 (3 logos): {'starkeypro.de', 'starkeypro.com.au', 'starkeypro.com'}
# Cluster 167 (3 logos): {'sto-sea.com', 'stosignature.com', 'sto.com.tr'}
# Cluster 168 (3 logos): {'synlab.cz', 'synlab.ec', 'synlab-notes.com'}
# Cluster 169 (3 logos): {'synlab.com.cy', 'synlab.com.mk', 'synlab.com.tr'}
# Cluster 170 (3 logos): {'synlab.si', 'synlab.com.hr', 'synlab.com.gh'}
# Cluster 171 (3 logos): {'trulynolenparaiba.com.br', 'trulynolengoias.com.br', 'trulynolenalagoas.com.br'}
# Cluster 172 (2 logos): {'adra.org.pt', 'adra.se'}
# Cluster 173 (2 logos): {'advocarenewbornnetwork.com', 'advocarewdp.com'}
# Cluster 174 (2 logos): {'aeccglobal.co.th', 'aeccglobal.co.id'}
# Cluster 175 (2 logos): {'affidea.ro', 'affidea.ba'}
# Cluster 176 (2 logos): {'algeco.sk', 'algeco.cz'}
# Cluster 177 (2 logos): {'analytik-jena.ru', 'analytik-jena.fr'}
# Cluster 178 (2 logos): {'axa-assistance.pl', 'axa-assistance.cz'}
# Cluster 179 (2 logos): {'axa-lifeeurope.com', 'axabreakdown.co.uk'}
# Cluster 180 (2 logos): {'babble.com', 'disneychannel.co.za'}
# Cluster 181 (2 logos): {'bakertilly.bg', 'bakertilly.com.cy'}
# Cluster 182 (2 logos): {'bakertilly.site', 'bakertilly.fr'}
# Cluster 183 (2 logos): {'bakertilly.se', 'bakertillysek.se'}
# Cluster 184 (2 logos): {'bauder.nl', 'bauder.be'}
# Cluster 185 (2 logos): {'bbraun.be', 'bbraun.nl'}
# Cluster 186 (2 logos): {'bbraun.co.uk', 'bbraun.com.my'}
# Cluster 187 (2 logos): {'berlitznouvelleaquitaine.fr', 'berlitzhautsdefrance.fr'}
# Cluster 188 (2 logos): {'bonprix.nl', 'bonprix-fl.be'}
# Cluster 189 (2 logos): {'bonprix.ch', 'bonprix.se'}
# Cluster 190 (2 logos): {'brother.com.ar', 'brother.co.il'}
# Cluster 191 (2 logos): {'carglass.hr', 'carglass.rs'}
# Cluster 192 (2 logos): {'carlsjrmerida.com', 'carlsjr.com.mx'}
# Cluster 193 (2 logos): {'cdvielectronics.com', 'cdviplastics.com'}
# Cluster 194 (2 logos): {'cfmotobenelux.eu', 'cfmotoitaly.it'}
# Cluster 195 (2 logos): {'chicco.fr', 'chicco.com.ph'}
# Cluster 196 (2 logos): {'cinnabonrussia.com', 'cinnabon.pk'}
# Cluster 197 (2 logos): {'compo-hobby.it', 'compo.pl'}
# Cluster 198 (2 logos): {'crocs.cl', 'crocs.pl'}
# Cluster 199 (2 logos): {'daikinmalaysia.com', 'daikin.com.mm'}
# Cluster 200 (2 logos): {'decathlon.cz', 'decathlon.ro'}
# Cluster 201 (2 logos): {'demeter.it', 'demeter-im-westen.de'}
# Cluster 202 (2 logos): {'duracell.pl', 'duracell.co.za'}
# Cluster 203 (2 logos): {'enterprise.com.ar', 'enterprise.dk'}
# Cluster 204 (2 logos): {'eurofins.at', 'eurofins.hr'}
# Cluster 205 (2 logos): {'eurofinsfoodtesting.com', 'eurofinsfoodtesting.nl'}
# Cluster 206 (2 logos): {'europcar.me', 'europcar.rs'}
# Cluster 207 (2 logos): {'experian.com.sg', 'experian.co.nz'}
# Cluster 208 (2 logos): {'funiber.org.uy', 'funiber.org.co'}
# Cluster 209 (2 logos): {'furuno.fr', 'furuno.it'}
# Cluster 210 (2 logos): {'globalconnect.dk', 'globalconnectgroup.com'}
# Cluster 211 (2 logos): {'greatplacetowork.com.sg', 'greatplacetowork.com.au'}
# Cluster 212 (2 logos): {'gs1lt.org', 'kia.am'}
# Cluster 213 (2 logos): {'hertz-autopozicovna.sk', 'hertz-autopujcovna.cz'}
# Cluster 214 (2 logos): {'hertz.am', 'hertz.com.ge'}
# Cluster 215 (2 logos): {'honda-autoland.com', 'hondasemarangcenter.com'}
# Cluster 216 (2 logos): {'hondamurcia.com', 'hondasevilla.net'}
# Cluster 217 (2 logos): {'howdentiger.com', 'howdenagents.gr'}
# Cluster 218 (2 logos): {'hyundai.sn', 'hyundai.ge'}
# Cluster 219 (2 logos): {'hyundaiblacktown.com.au', 'hyundaichullora.com.au'}
# Cluster 220 (2 logos): {'hyundaigatineau.ca', 'lamborghinimontreal.com'}
# Cluster 221 (2 logos): {'ikea.com.hk', 'ikea.co.id'}
# Cluster 222 (2 logos): {'ikea.com.do', 'ikea.is'}
# Cluster 223 (2 logos): {'inductotherm.com.cn', 'inductotherm-group-france.fr'}
# Cluster 224 (2 logos): {'infiniti-jordan.com', 'infiniti-dubai.com'}
# Cluster 225 (2 logos): {'infiniti.com.do', 'infiniti.com.pa'}
# Cluster 226 (2 logos): {'isic.it', 'isic.fr'}
# Cluster 227 (2 logos): {'isuzuhanoi.com', 'isuzu-vietnam.com'}
# Cluster 228 (2 logos): {'kia-exner.de', 'kia-beyschlag.at'}
# Cluster 229 (2 logos): {'komoder.com', 'komoder.co.uk'}
# Cluster 230 (2 logos): {'lamborghini-cannes.com', 'lamborghini-stuttgart.com'}
# Cluster 231 (2 logos): {'vendhq.com', 'lightspeedhq.fr'}
# Cluster 232 (2 logos): {'linak.es', 'linak.nl'}
# Cluster 233 (2 logos): {'linde-amt.com', 'linde-gas.com'}
# Cluster 234 (2 logos): {'lindesaude.pt', 'linde-medica.es'}
# Cluster 235 (2 logos): {'linde.bo', 'linde.pe'}
# Cluster 236 (2 logos): {'manpowergroup.dk', 'manpowergroup.com.sg'}
# Cluster 237 (2 logos): {'medef-artois.fr', 'medef-nouvelle-aquitaine.fr'}
# Cluster 238 (2 logos): {'menicon.com.au', 'menicon.sg'}
# Cluster 239 (2 logos): {'metlife.com.au', 'metlife.com.ar'}
# Cluster 240 (2 logos): {'monster.co.uk', 'monster.ie'}
# Cluster 241 (2 logos): {'mtn.cg', 'mtn.ci'}
# Cluster 242 (2 logos): {'murrelektronik.es', 'murrelektronik.se'}
# Cluster 243 (2 logos): {'nestle.com.vn', 'nestle.se'}
# Cluster 244 (2 logos): {'nexi.hr', 'nexi.gr'}
# Cluster 245 (2 logos): {'nobleprog.com.eg', 'nobleprog.ae'}
# Cluster 246 (2 logos): {'nobleprog.mx', 'nobleprog.com.ar'}
# Cluster 247 (2 logos): {'nutricia.co.uk', 'nutricia.ie'}
# Cluster 248 (2 logos): {'patheon.com', 'patheon.kr'}
# Cluster 249 (2 logos): {'pearsonclinical.fr', 'pearsonclinical.es'}
# Cluster 250 (2 logos): {'pefc.org', 'pefc.fi'}
# Cluster 251 (2 logos): {'pilotpen.co.uk', 'pilotpen.eu'}
# Cluster 252 (2 logos): {'plameco-baer.de', 'plameco-rheinsieg.de'}
# Cluster 253 (2 logos): {'plameco.nl', 'plameco.be'}
# Cluster 254 (2 logos): {'plastoplan.rs', 'plastoplan.pl'}
# Cluster 255 (2 logos): {'remax-pinneberg.de', 'remax-lueneburg.de'}
# Cluster 256 (2 logos): {'renaultrycauto.es', 'renault-tortosa.es'}
# Cluster 257 (2 logos): {'rsmcanada.com', 'rsmuk.com'}
# Cluster 258 (2 logos): {'santillana.com.sv', 'santillana.com.hn'}
# Cluster 259 (2 logos): {'savethechildren.nl', 'savethechildren.org.uk'}
# Cluster 260 (2 logos): {'shimadzu.com.ph', 'shimadzu.com.cn'}
# Cluster 261 (2 logos): {'siebtechnik-tema.nl', 'siebtechnik-tema.cn'}
# Cluster 262 (2 logos): {'siebtechnik-tema.co.uk', 'siebtechnik-tema.com.au'}
# Cluster 263 (2 logos): {'spie.be', 'spie.lu'}
# Cluster 264 (2 logos): {'subarusouthblvd.com', 'subarusouthpoint.com'}
# Cluster 265 (2 logos): {'takeda.nl', 'takeda.com.ru'}
# Cluster 266 (2 logos): {'tbwa.co.za', 'tbwa-entelia.com'}
# Cluster 267 (2 logos): {'toyota-saint-victoret.com', 'toyota-marseille.com'}
# Cluster 268 (2 logos): {'toyota.com.mk', 'toyotaalbania.al'}
# Cluster 269 (2 logos): {'toyota.com.mt', 'toyotadolak.cz'}
# Cluster 270 (2 logos): {'toyotaploiesti.ro', 'toyotaconstanta.ro'}
# Cluster 271 (2 logos): {'toyotadefence.com', 'toyotasouthern.com'}
# Cluster 272 (2 logos): {'toysrus.com.sg', 'toysrus.com.my'}
# Cluster 273 (2 logos): {'toysrus.fr', 'toysrus.de'}
# Cluster 274 (2 logos): {'trulynolenbarueri.com.br', 'trulynolenrecife.com.br'}
# Cluster 275 (2 logos): {'unicharm.co.in', 'unicharm.com.br'}
# Cluster 276 (2 logos): {'vans.es', 'vans.at'}
# Cluster 277 (2 logos): {'vans.fr', 'vans.nl'}
# Cluster 278 (2 logos): {'veolia.com.sg', 'veolia.am'}
# Cluster 279 (2 logos): {'veolia.ca', 'veolianorthamerica.com'}
# Cluster 280 (2 logos): {'viacon.no', 'viacon.fi'}
# Cluster 281 (2 logos): {'wordans.it', 'wordans.de'}
# Cluster 282 (2 logos): {'wurth.com.tw', 'wurth-international.com.cn'}
# Cluster 283 (2 logos): {'wurth.com.mk', 'wurth.rs'}
# Cluster 284 (2 logos): {'wwf.org.nz', 'wwf.org'}
# Cluster 285 (2 logos): {'yves-rocher.pt', 'yves-rocher.it'}

# %% [markdown]
# ## Scraping Accuracy

# %%
import pandas as pd
total_domains = pd.read_parquet('logos.snappy.parquet')
total_domains = total_domains['domain'].unique().tolist()

print(f"\n✅ Logos processed: {len(valid_domains)} / {len(total_domains)} ({100 * len(valid_domains)/len(total_domains):.2f}%)")
# Out:
# ✅ Logos processed: 3400 / 3416 (99.53%)
